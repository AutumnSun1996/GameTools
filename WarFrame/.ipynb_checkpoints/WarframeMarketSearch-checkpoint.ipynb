# %%
import pyquery
import requests
import re
import json
import pandas as pd
import win32clipboard

trans_url = "https://warframe.huijiwiki.com/wiki/UserDict"
print("获取翻译。。。")
trans_content = pyquery.PyQuery(trans_url)("#mw-content-text").html()
trans_items = re.findall('<tr><th>([^<>]+?)</th><td class="value">"([^<>]+?)"</td></tr>', trans_content.replace("&amp;", "&"))
trans_dict = {k:v for v, k in trans_items}
retrans_dict = {k:v for k, v in trans_items}

ua = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36"

def get_wm_data(url):
    print("Get From:", url)
    res = requests.get(url, headers={"User-Agent": ua})
    pq = pyquery.PyQuery(res.text)
    script = pq("script#application-state").html()
    return json.loads(script)

print("获取物品列表。。。")
wm_url = "https://warframe.market/"
wm_info = get_wm_data(wm_url)
wm_items = {item['item_name']:item['url_name'] for item in wm_info['items']['en']}


add_ons = [
    ("Primed ", ""),
    
    ("", ""),
    ("", " Set"),
    ("", " Prime"),
    ("", " Prime Set"),
    ("", " Vandal"),
    ("", " Vandal Set"),
    ("", " Wraith"),
    ("", " Wraith Set"),
    ("Wraith ", " Set"),
    ("Prisma ", ""),
    ("", " Ayatan Sculpture"),
    
    ("Rakta ", ""),
    ("Sancti ", ""),
    ("Secura ", ""),
    ("Synoid ", ""),
    ("Telos ", ""),
]

def en2ch(name):
    if name in retrans_dict:
        return retrans_dict[name]
    for en, ch in trans_items:
        name = name.replace(en, ch)
    return name

def get_item_data(unit_name):
    unit_name = trans_dict.get(unit_name, unit_name)
    for pre, suf  in add_ons:
        tmp = pre + unit_name + suf
#         print(tmp, tmp in wm_items)
        if tmp in wm_items:
            unit_name = tmp
            break

    url = wm_url + 'items/' + wm_items[unit_name]
    info = get_wm_data(url)
    info['name'] = unit_name
    return info

def set_clipboard_text(text):
    win32clipboard.OpenClipboard()
    win32clipboard.SetClipboardText(text, win32clipboard.CF_UNICODETEXT)
    win32clipboard.CloseClipboard()

def set_message(df):
    name = df.index.name
    if name.endswith(" Set"):
        name = "[" + name[:-4] + "] Set"
    else:
        name = "[" + name + "]"
    set_clipboard_text("/w {1.name} Hi! I want to buy: {0} for {1[platinum]} platinum.".format(name, df.iloc[0]))

def order_filter(order):
    return True
    
def orders2df(info):
    orders = [{
        "order_type":item["order_type"],
        "platform":item["platform"],
        "platinum":item["platinum"],
        "quantity":item["quantity"],
        "visible":item["visible"],
        "rank":item.get('mod_rank'),
        "user_name":item["user"]['ingame_name'],
        "user_status":item["user"]['status']
    } for item in info['payload']['orders'] if order_filter(item)]
    df = pd.DataFrame(orders).set_index("user_name")
    if "mod_max_rank" not in info["include"]["item"]["items_in_set"][0]:
        df.drop("rank", axis=1, inplace=True)
    else:
        df.dropna(subset=["rank"], inplace=True)
    df.index.name = info["name"]
    return df

def filt_orders(df, order_type="sell", rank=None, copy=True):
    sell_orders = df[(df['order_type'] == order_type) & (df['user_status'] == 'ingame') & df['visible']]
    try:
        sell_orders = sell_orders.drop(["platform", "user_status", "visible"], axis=1)
    except:
        pass
    if rank is not None:
        sell_orders = sell_orders[sell_orders['rank'] == rank]
    sell_orders = sell_orders.sort_values("platinum", ascending=(order_type == 'sell'))
    if copy:
        set_message(sell_orders)
    return sell_orders #[['platinum', 'quantity']]

def get_set_data(item_name):
    info =  get_item_data(item_name)
    return show_set_data(info)

def show_set_data(info):
    data = orders2df(info)
    sell = filt_orders(data, 'sell', copy=False)
    
    items = []
    print(en2ch(info["name"]))
    print(sell.iloc[0]['platinum'])
    items.append({"Name": info["name"], "Data": data})
    total = 0
    for item in info['include']['item']['items_in_set']:
        if not item['set_root']:
            part_info = get_item_data(item['en']['item_name'])
            data = orders2df(part_info)
            sell = filt_orders(data, 'sell', copy=False)
            items.append({"Name": item['en']['item_name'], "Data": data})
            print(en2ch(item['en']['item_name']))
            print(sell.iloc[0]['platinum'])
            total += sell.iloc[0]['platinum']
    print(total)
    return items
    
def show_item_data(item_name, order_type="sell", ranks=None, copy=True, deal_set=True):
    info =  get_item_data(item_name)
    if deal_set and info["name"].endswith(" Set"):
        show_set_data(info)
        return
        
    print(en2ch(info["name"]))
    data = orders2df(info)
    
    if "rank" not in data.columns:
        sell = filt_orders(data, order_type, copy=copy)
        print(sell.head())
        return
        
    if ranks is None:
        ranks = [0, "max"]
        
    if "max" in ranks:
        ranks.remove("max")
        max_rank = data["rank"].max()
        if max_rank:
            ranks.append(max_rank)
            
    for rank in ranks:
        sell = filt_orders(data, order_type, rank, copy=copy)
        print(sell.head())
        print()
    # return data

def main():
    while True:
        name = input("名称:")
        if name == "":
            return 
        try:
            if name.startswith("buy "):
                show_item_data(name[4:], "buy")
            else:
                show_item_data(name)
        except Exception as err:
            print(err)
# Out:
# 获取翻译。。。
# 获取物品列表。。。
# Get From: https://warframe.market/
# 名称:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\Software\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# D:\Software\Anaconda3\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# D:\Software\Anaconda3\lib\site-packages\zmq\sugar\socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq\backend\cython\socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq\backend\cython\socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq\backend\cython\socket.c:2344)()
#
# D:\Software\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq\backend\cython\socket.c:9621)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-32988d901de2> in <module>()
#     188
#     189 if __name__ == "__main__":
# --> 190     main()
#     191
#     192     for name in "诡计 速攻 狂怒 节奏 消磁".split(" "):
#
# <ipython-input-1-32988d901de2> in main()
#     175 def main():
#     176     while True:
# --> 177         name = input("名称:")
#     178         if name == "":
#     179             return
#
# D:\Software\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# D:\Software\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
def order_filter(order):
    return order["user"]['region'] == 'en'

# %%
for name in "心志偏狭 盲怒 瞬时坚毅 重口径".split(" "):
    show_item_data(name, ranks=["max"], deal_set=False)
# Out:
# Get From: https://warframe.market/items/narrow_minded
# 心志偏狭
#               order_type  platinum  quantity  rank
# Narrow Minded
# AddyHunter          sell       220         1    10
# AddyHunter          sell       220         1    10
# AutumnSun1996       sell       240         2    10
# SK_Raze             sell       248         1    10
# Love_GooooD         sell       250         1    10
#
# Get From: https://warframe.market/items/blind_rage
# 盲怒
#                 order_type  platinum  quantity  rank
# Blind Rage
# Teonanacatl.          sell       195         1    10
# YosioTheRainbow       sell       200         1    10
# FilthyHobbitZA        sell       210         1    10
# Cyberdriver           sell       240         1    10
# Fayabraz              sell       250         1    10
#
# Get From: https://warframe.market/items/transient_fortitude
# 瞬时坚毅
#                          order_type  platinum  quantity  rank
# Transient Fortitude
# CaptainGohn                    sell       220         1    10
# Bulllets                       sell       242         1    10
# -----sladkaya_bulochka--       sell       243         1    10
# Fayabraz                       sell       250         1    10
# Love_GooooD                    sell       250         1    10
#
# Get From: https://warframe.market/items/heavy_caliber
# 重口径
#                          order_type  platinum  quantity  rank
# Heavy Caliber
# -----sladkaya_bulochka--       sell       190         1    10
# Kyleman2342                    sell       190         1    10
# namuless                       sell       194         2    10
# DarK_Berserker                 sell       195         1    10
# DerpDonut987                   sell       200         1    10

# %%
main()
# Out:
# 名称:抵近射击
# Get From: https://warframe.market/items/primed_point_blank
# 抵近射击Prime
#                    order_type  platinum  quantity  rank
# Primed Point Blank
# Kripser                  sell        95         6     0
# globus009                sell        99         1     0
# Booben                   sell        99         5     0
# war_hawk15               sell        99         2     0
# GZeroDaniel              sell       100         1     0
#
#                    order_type  platinum  quantity  rank
# Primed Point Blank
# Jokey                    sell       400         1    10
# -AstralDawn-             sell       400         1    10
# BenRich                  sell       400         2    10
# CindyLu                  sell       450         1    10
# --MEGALODON--            sell       550         3    10
#
# 名称:压迫点
# Get From: https://warframe.market/items/primed_pressure_point
# 压迫点Prime
#                       order_type  platinum  quantity  rank
# Primed Pressure Point
# Xergh                       sell       115         1     0
# .Dely.                      sell       119         2     0
# SY-18r                      sell       120        10     0
# VilgefortzOfRoggeveen       sell       120         1     0
# TheAmazingEternals          sell       120         9     0
#
#                       order_type  platinum  quantity  rank
# Primed Pressure Point
# angry_worms                 sell       395         1    10
# sinistr_sausage             sell       399         1    10
# VilgefortzOfRoggeveen       sell       400         1    10
# kurisu                      sell       450        10    10
# -TSA-Westberliner           sell       500         1    10
#
# 名称:火焰装填
# Get From: https://warframe.market/items/primed_heated_charge
# 火焰装填Prime
#                      order_type  platinum  quantity  rank
# Primed Heated Charge
# Hempten                    sell        40         2     0
# BbosicK2                   sell       120         4     0
# Saymos95                   sell       120         1     0
# yangyangxx                 sell       120         1     0
# Weckenstein                sell       140         1     0
#
#                      order_type  platinum  quantity  rank
# Primed Heated Charge
# Deltren                    sell       499         1    10
# --MEGALODON--              sell       500         3    10
#
# 名称:手枪精通
# Get From: https://warframe.market/items/primed_pistol_gambit
# 手枪精通Prime
#                      order_type  platinum  quantity  rank
# Primed Pistol Gambit
# JohnVane                   sell       120         1     0
# yangyangxx                 sell       120         1     0
# Kripser                    sell       125         1     0
# GR33N-4RROW                sell       130         1     0
# Matteoz991                 sell       140         1     0
#
#                      order_type  platinum  quantity  rank
# Primed Pistol Gambit
# BOBAH_0451                 sell       370         1    10
# xX_SoulEater_Xx            sell       399         1    10
# -Night-Fury-               sell       400         1    10
# --MEGALODON--              sell       550         3    10
# U3FeXeE                    sell       599         1    10
#
# 名称:弱点专精
# Get From: https://warframe.market/items/primed_target_cracker
# 弱点专精Prime
#                       order_type  platinum  quantity  rank
# Primed Target Cracker
# Hempten                     sell        44         1     0
# SgtGitaroo                  sell        89         1     0
# StrelecMemec2007            sell        90         1     0
# jesse1110                   sell        90         5     0
# Kripser                     sell        90         4     0
#
#                       order_type  platinum  quantity  rank
# Primed Target Cracker
# BOBAH_0451                  sell       340         1    10
# Love_GooooD                 sell       350         1    10
# Deltren                     sell       389         1    10
# XenophageKnight             sell       390         1    10
# MRBARAGON                   sell       395         1    10
#
# 名称:

# %%
380*1.2
# Out:
# 456.0

# %%
11608*1.3
# Out:
# 15090.4

# %%
for item in info['payload']['orders']:
    if "mod_rank" not in item:
        print(item)

# %%
show_item_data("消磁赋能")
# Out:
# Get From: https://warframe.market/items/arcane_nullifier
# 消磁赋能
#                  order_type  platinum  quantity  rank
# Arcane Nullifier
# Drackvs                sell        10         5   0.0
# Pariah_Code            sell        10         2   0.0
# Jokey                  sell        10        10   0.0
# lWrathOfWarl           sell        10        14   0.0
# TheFallen86            sell        10         2   0.0
#
#                  order_type  platinum  quantity  rank
# Arcane Nullifier
# raze_the_world         sell        70         1   3.0
# PlayersUnited          sell        75         1   3.0
# SaDNeSSs               sell        80         1   3.0
# Twilight_Warrior       sell        80         2   3.0
# YourWifeMyKids         sell        80         1   3.0

# %%
show_item_data("重口径")
# Out:
# Get From: https://warframe.market/items/heavy_caliber
# 重口径
#                        order_type  platinum  quantity  rank
# Heavy Caliber
# Sevenend                     sell        19         1     0
# SusuPadilla                  sell        19         1     0
# SoldMemstoHilterGitGud       sell        20         2     0
# T.I.P.                       sell        20         6     0
# Zeltium                      sell        20         1     0
#
#                          order_type  platinum  quantity  rank
# Heavy Caliber
# -----sladkaya_bulochka--       sell       190         1    10
# Kyleman2342                    sell       190         1    10
# namuless                       sell       194         2    10
# DarK_Berserker                 sell       195         1    10
# DerpDonut987                   sell       200         1    10

# %%
import pyquery
import requests
import re
import json
import pandas as pd
import win32clipboard

# %%
# %load wms.py
import pyquery
import requests
import re
import json
import pandas as pd
import win32clipboard

trans_url = "https://warframe.huijiwiki.com/wiki/UserDict"
print("获取翻译。。。")
trans_content = pyquery.PyQuery(trans_url)("#mw-content-text").html()
trans_items = re.findall('<tr><th>([^<>]+?)</th><td class="value">"([^<>]+?)"</td></tr>', trans_content.replace("&amp;", "&"))
trans_dict = {k:v for v, k in trans_items}
retrans_dict = {k:v for k, v in trans_items}

ua = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36"

def get_wm_data(url):
    print("Get From:", url)
    res = requests.get(url, headers={"User-Agent": ua})
    pq = pyquery.PyQuery(res.text)
    script = pq("script#application-state").html()
    return json.loads(script)

print("获取物品列表。。。")
wm_url = "https://warframe.market/"
wm_info = get_wm_data(wm_url)
wm_items = {item['item_name']:item['url_name'] for item in wm_info['items']['en']}


add_ons = [
    ("Primed ", ""),
    
    ("", ""),
    ("", " Set"),
    ("", " Prime"),
    ("", " Prime Set"),
    ("", " Vandal"),
    ("", " Vandal Set"),
    ("", " Wraith"),
    ("", " Wraith Set"),
    ("Wraith ", " Set"),
    ("Prisma ", ""),
    ("", " Ayatan Sculpture"),
    
    ("Rakta ", ""),
    ("Sancti ", ""),
    ("Secura ", ""),
    ("Synoid ", ""),
    ("Telos ", ""),
]

def en2ch(name):
    if name in retrans_dict:
        return retrans_dict[name]
    for en, ch in trans_items:
        name = name.replace(en, ch)
    return name

def get_item_data(unit_name):
    unit_name = trans_dict.get(unit_name, unit_name)
    for pre, suf  in add_ons:
        tmp = pre + unit_name + suf
#         print(tmp, tmp in wm_items)
        if tmp in wm_items:
            unit_name = tmp
            break

    url = wm_url + 'items/' + wm_items[unit_name]
    info = get_wm_data(url)
    info['name'] = unit_name
    return info

def set_clipboard_text(text):
    win32clipboard.OpenClipboard()
    win32clipboard.SetClipboardText(text, win32clipboard.CF_UNICODETEXT)
    win32clipboard.CloseClipboard()

def set_message(df):
    name = df.index.name
    if name.endswith(" Set"):
        name = "[" + name[:-4] + "] Set"
    else:
        name = "[" + name + "]"
    set_clipboard_text("/w {1.name} Hi! I want to buy: {0} for {1[platinum]} platinum.".format(name, df.iloc[0]))

def orders2df(info):
    orders = [{
        "order_type":item["order_type"],
        "platform":item["platform"],
        "platinum":item["platinum"],
        "quantity":item["quantity"],
        "visible":item["visible"],
        "rank":item.get('rank', item.get('mod_rank')),
        "user_name":item["user"]['ingame_name'],
        "user_status":item["user"]['status']
    } for item in info['payload']['orders']]
    df = pd.DataFrame(orders).set_index("user_name")
    if set(df["rank"]) == {None}:
        df.drop("rank", axis=1, inplace=True)
    df.index.name = info["name"]
    return df

def filt_orders(df, order_type="sell", rank=None, copy=True):
    sell_orders = df[(df['order_type'] == order_type) & (df['user_status'] == 'ingame') & df['visible']]
    try:
        sell_orders = sell_orders.drop(["platform", "user_status", "visible"], axis=1)
    except:
        pass
    if rank is not None:
        sell_orders = sell_orders[sell_orders['rank'] == rank]
    sell_orders = sell_orders.sort_values("platinum", ascending=(order_type == 'sell'))
    if copy:
        set_message(sell_orders)
    return sell_orders #[['platinum', 'quantity']]

def get_set_data(item_name):
    items = []
    info =  get_item_data(item_name)
    data = orders2df(info)
    sell = filt_orders(data, 'sell', copy=False)
    
    print(en2ch(info["name"]))
    print(sell.iloc[0]['platinum'])
    items.append({"Name": item_name, "Data": data})
    total = 0
    for item in info['include']['item']['items_in_set']:
        if not item['set_root']:
            part_info = get_item_data(item['en']['item_name'])
            data = orders2df(part_info)
            sell = filt_orders(data, 'sell', copy=False)
            items.append({"Name": item['en']['item_name'], "Data": data})
            print(en2ch(item['en']['item_name']))
            print(sell.iloc[0]['platinum'])
            total += sell.iloc[0]['platinum']
    print(total)
    return items

def show_item_data(item_name, order_type="sell", ranks=None, copy=True):
    info =  get_item_data(item_name)
    print(en2ch(info["name"]))
    data = orders2df(info)
    
    if "rank" not in data.columns:
        sell = filt_orders(data, order_type, copy=copy)
        print(sell.head())
        return
        
    if ranks is None:
        ranks = [0]
        max_rank = data["rank"].max()
        if max_rank:
            ranks.append(max_rank)
            
    for rank in ranks:
        sell = filt_orders(data, order_type, rank, copy=copy)
        print(sell.head())
        print()
    # return data

def main():
    while True:
        name = input("名称:")
        if name == "":
            return 
        try:
            show_item_data(name)
        except Exception as err:
            print(err)
            
            
if __name__ == "__main__":
    main()
# Out:
# 获取翻译。。。
# 获取物品列表。。。
# Get From: https://warframe.market/
# Get From: https://warframe.market/items/primed_continuity
# 持久力Prime
#                   order_type  platinum  quantity  rank
# Primed Continuity
# NightHorror888          sell       100         1     0
# GoDGoR.kh               sell       100         1     0
# xTigerLilyx             sell       110         2     0
# tiggyCRO                sell       125         1     0
# OhaLanKacVurdu          sell       145         1     0
#
#                    order_type  platinum  quantity  rank
# Primed Continuity
# WanderingCaretaker       sell       369         1    10
# lSuperLovel              sell       398         1    10
# Lucidini                 sell       400         1    10
# iPanicShooW              sell       500         1    10
# --Juvia-Lockser--        sell       500         1    10
#
# 名称:'
# "'"
# 名称:

# %%
def orders2df(info):
    orders = [{
        "order_type":item["order_type"],
        "platform":item["platform"],
        "platinum":item["platinum"],
        "quantity":item["quantity"],
        "visible":item["visible"],
        "rank":item.get('rank', item.get('mod_rank')),
        "user_name":item["user"]['ingame_name'],
        "user_status":item["user"]['status']
    } for item in info['payload']['orders']]
    df = pd.DataFrame(orders).set_index("user_name")
    df.dropna(axis=1, how="any", inplace=True)
    df.index.name = info["name"]
    return df

# %%
show_item_data("Bo")
# Out:
# Get From: https://warframe.market/items/bo_prime_set
# 玻之武杖 Prime Set
#                       order_type  platinum  quantity
# Bo Prime Set
# inappropriatename5761       sell        89         1
# ZombieTrooper               sell        90         1
# Yumskie                     sell        95         1
# CaptianFlail                sell        99         1
# campoi                      sell       120         1

# %%
info =  get_item_data("Bo")
print(en2ch(info["name"]))
data = orders2df(info)

if "rank" not in data.columns:
    sell = filt_orders(data, order_type, copy=copy)
    print(sell.head())
# Out:
# Get From: https://warframe.market/items/bo_prime_set
# 玻之武杖 Prime Set

# %%
help(data.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(axis=0, how='any', thresh=None, subset=None, inplace=False) method of pandas.core.frame.DataFrame instance
#     Return object with labels on given axis omitted where alternately any
#     or all of the data are missing
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, or tuple/list thereof
#         Pass tuple or list to drop on multiple axes
#     how : {'any', 'all'}
#         * any : if any NA values are present, drop that label
#         * all : if all values are NA, drop that label
#     thresh : int, default None
#         int value : require that many non-NA values
#     subset : array-like
#         Labels along other axis to consider, e.g. if you are dropping rows
#         these would be a list of columns to include
#     inplace : boolean, default False
#         If True, do operation inplace and return None.
#
#     Returns
#     -------
#     dropped : DataFrame
#
#     Examples
#     --------
#     >>> df = pd.DataFrame([[np.nan, 2, np.nan, 0], [3, 4, np.nan, 1],
#     ...                    [np.nan, np.nan, np.nan, 5]],
#     ...                   columns=list('ABCD'))
#     >>> df
#          A    B   C  D
#     0  NaN  2.0 NaN  0
#     1  3.0  4.0 NaN  1
#     2  NaN  NaN NaN  5
#
#     Drop the columns where all elements are nan:
#
#     >>> df.dropna(axis=1, how='all')
#          A    B  D
#     0  NaN  2.0  0
#     1  3.0  4.0  1
#     2  NaN  NaN  5
#
#     Drop the columns where any of the elements is nan
#
#     >>> df.dropna(axis=1, how='any')
#        D
#     0  0
#     1  1
#     2  5
#
#     Drop the rows where all of the elements are nan
#     (there is no row to drop, so df stays the same):
#
#     >>> df.dropna(axis=0, how='all')
#          A    B   C  D
#     0  NaN  2.0 NaN  0
#     1  3.0  4.0 NaN  1
#     2  NaN  NaN NaN  5
#
#     Keep only the rows with at least 2 non-na values:
#
#     >>> df.dropna(thresh=2)
#          A    B   C  D
#     0  NaN  2.0 NaN  0
#     1  3.0  4.0 NaN  1

# %%
data.dropna(axis=1, how='any').head()
# Out:
#                 order_type platform  platinum  quantity user_status  visible
# Bo Prime Set
# -SHARDS-              sell       pc       250         2     offline     True
# D4M4G3                sell       pc       300         5     offline     True
# IamRageypoo           sell       pc       500         1     offline     True
# SnakeMittens          sell       pc       200         1      ingame     True
# --I-.Zylux.-I--       sell       pc       250         1     offline     True

# %%
for item in info["payload"]["orders"]:
    if "rank" in item or "mod_rank" in item:
        print(item)
# Out:
# {'platform': 'pc', 'quantity': 2, 'last_update': 'iso', 'user': {'reputation': 3, 'reputation_bonus': 0, 'avatar': 'user/avatar/56acc72cd3ffb6140b1b2c96.png?e469717772daf9acf05d3bb6b5ce0ac7', 'ingame_name': 'k3blin', 'status': 'offline', 'last_seen': '2018-04-08T08:40:17.326000+00:00', 'region': 'en', 'id': '56acc72cd3ffb6140b1b2c96'}, 'visible': True, 'platinum': 100, 'id': '5ac29c857684a1068a20cadc', 'order_type': 'sell', 'mod_rank': 5, 'creation_date': 'iso', 'region': 'en'}
# {'mod_rank': 0, 'visible': True, 'last_update': 'iso', 'user': {'reputation': 0, 'reputation_bonus': 0, 'avatar': None, 'ingame_name': 'TheShadowN1NJA', 'status': 'offline', 'last_seen': '2018-04-16T07:53:58.389000+00:00', 'region': 'en', 'id': '5aa6090e69f30601c860fdf4'}, 'platform': 'pc', 'platinum': 80, 'quantity': 1, 'order_type': 'sell', 'region': 'en', 'creation_date': 'iso', 'id': '5ac9233a69f3060771baa3c9'}

# %%
data.isna
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-421a78ad53f8> in <module>()
# ----> 1 data.isna
#
# D:\Software\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
def show_item_data(item_name, order_type="sell", ranks=None, copy=True):
    info =  get_item_data(item_name)
    print(en2ch(info["name"]))
    data = orders2df(info)
    
    if "rank" not in data.columns:
        sell = filt_orders(data, order_type, rank, copy=copy)
        print(sell.head())
        return
        
    if ranks is None:
        ranks = [0]
        max_rank = data["rank"].max()
        if max_rank > 0:
            ranks.append(max_rank)
            
    for rank in ranks:
        sell = filt_orders(data, order_type, rank, copy=copy)
        print(sell.head())
        print()

# %%
show_item_data("狂怒赋能")
# Out:
# Get From: https://warframe.market/items/arcane_fury
# 奥秘 狂暴
#             order_type  platinum  quantity  rank
# Arcane Fury
# albertsmn         sell        50         1   0.0
# ChakalZero        sell        50         1   0.0
# Khrillian         sell        55         5   0.0
# llLuciifer        sell        55         2   0.0
# -CCC-Snow         sell        55         1   0.0
#
#                     order_type  platinum  quantity  rank
# Arcane Fury
# Be_Gentle_Onii_Chan       sell       600         2   3.0
# -CG-gucci                 sell       680         1   3.0
# Grumpisaurus              sell       690         1   3.0
# KamikaZBr                 sell       690         1   3.0
# Dao219                    sell       700         1   3.0

# %%
en2ch("Arcane Fury")
# Out:
# '奥秘 狂暴'

# %%
retrans_dict.get("Arcane Fury")
# Out:
# '狂怒赋能'

# %%
trans_url = "https://warframe.huijiwiki.com/wiki/UserDict"
trans_content = pyquery.PyQuery(trans_url)("#mw-content-text").html()
trans_items = re.findall('<tr><th>([^<>]+?)</th><td class="value">"([^<>]+?)"</td></tr>', trans_content.replace("&amp;", "&"))
trans_dict = {k:v for v, k in trans_items}
retrans_dict = {k:v for k, v in trans_items}

# %%
ua = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36"

def get_wm_data(url):
    print("Get From:", url)
    res = requests.get(url, headers={"User-Agent": ua})
    pq = pyquery.PyQuery(res.text)
    script = pq("script#application-state").html()
    return json.loads(script)

wm_url = "https://warframe.market/"
wm_info = get_wm_data(wm_url)
wm_items = {item['item_name']:item['url_name'] for item in wm_info['items']['en']}
# Out:
# Get From: https://warframe.market/

# %%
add_ons = [
    ("", ""),
    ("", " Set"),
    ("", " Prime"),
    ("", " Prime Set"),
    ("", " Vandal"),
    ("", " Vandal Set"),
    ("", " Wraith"),
    ("", " Wraith Set"),
    ("Wraith ", " Set"),
    ("Prisma ", ""),
    
    ("Primed ", ""),
    
    ("Rakta ", ""),
    ("Sancti ", ""),
    ("Secura ", ""),
    ("Synoid ", ""),
    ("Telos ", ""),
    
]

def en2ch(name):
    for en, ch in trans_items:
        name = name.replace(en, ch)
    return name

def get_item_data(unit_name):
    unit_name = trans_dict.get(unit_name, unit_name)
    for pre, suf  in add_ons:
        tmp = pre + unit_name + suf
#         print(tmp, tmp in wm_items)
        if tmp in wm_items:
            unit_name = tmp
            break

    url = wm_url + 'items/' + wm_items[unit_name]
    info = get_wm_data(url)
    info['name'] = unit_name
    return info

# %%
def set_clipboard_text(text):
    win32clipboard.OpenClipboard()
    win32clipboard.SetClipboardText(text, win32clipboard.CF_UNICODETEXT)
    win32clipboard.CloseClipboard()

def set_message(df):
    name = df.index.name
    if name.endswith(" Set"):
        name = "[" + name[:-4] + "] Set"
    else:
        name = "[" + name + "]"
    set_clipboard_text("/w {1.name} Hi! I want to buy: {0} for {1[platinum]} platinum.".format(name, df.iloc[0]))

# %%
def orders2df(info):
    orders = [{
        "order_type":item["order_type"],
        "platform":item["platform"],
        "platinum":item["platinum"],
        "quantity":item["quantity"],
        "visible":item["visible"],
        "rank":item.get('rank', item.get('mod_rank')),
        "user_name":item["user"]['ingame_name'],
        "user_status":item["user"]['status']
    } for item in info['payload']['orders']]
    df = pd.DataFrame(orders).set_index("user_name")
    if set(df["rank"]) == {None}:
        df.drop("rank", axis=1, inplace=True)
    df.index.name = info["name"]
    return df

def filt_orders(df, order_type="sell", rank=None, copy=True):
    sell_orders = df[(df['order_type'] == order_type) & (df['user_status'] == 'ingame') & df['visible']]
    if rank is not None:
        sell_orders = sell_orders[sell_orders['rank'] == rank]
    sell_orders = sell_orders.sort_values("platinum", ascending=(order_type == 'sell'))
    if copy:
        set_message(sell_orders)
    return sell_orders #[['platinum', 'quantity']]

# %%
def get_set_data(item_name):
    items = []
    info =  get_item_data(item_name)
    data = orders2df(info)
    sell = filt_orders(data, 'sell', copy=False)
    
    print(en2ch(info["name"]))
    print(sell.iloc[0]['platinum'])
    items.append({"Name": item_name, "Data": data})
    total = 0
    for item in info['include']['item']['items_in_set']:
        if not item['set_root']:
            part_info = get_item_data(item['en']['item_name'])
            data = orders2df(part_info)
            sell = filt_orders(data, 'sell', copy=False)
            items.append({"Name": item['en']['item_name'], "Data": data})
            print(en2ch(item['en']['item_name']))
            print(sell.iloc[0]['platinum'])
            total += sell.iloc[0]['platinum']
    print(total)
    return items

def show_item_data(item_name, order_type="sell", rank=None, copy=True):
    info =  get_item_data(item_name)
    print(en2ch(info["name"]))
    data = orders2df(info)
    sell = filt_orders(data, order_type, rank, copy=copy)
    best_price = sell.iloc[0]['platinum']
    return sell.head()

# %%
show_item_data("诡计赋能")
# Out:
# Get From: https://warframe.market/items/arcane_trickery
# 诡计赋能
#                 order_type platform  platinum  quantity  rank user_status  \
# Arcane Trickery
# SledjHammr            sell       pc         8         2   0.0      ingame
# pian96                sell       pc         9         3   0.0      ingame
# biltok                sell       pc         9         1   0.0      ingame
# MarkyGMBro            sell       pc        10         3   0.0      ingame
# Bongdrokz             sell       pc        10         3   0.0      ingame
#
#                  visible
# Arcane Trickery
# SledjHammr          True
# pian96              True
# biltok              True
# MarkyGMBro          True
# Bongdrokz           True

# %%
show_item_data("保卫者赋能")
# Out:
# Get From: https://warframe.market/items/arcane_guardian
# 奥秘 守护者
#                 order_type platform  platinum  quantity  rank user_status  \
# Arcane Guardian
# streetknowledge       sell       pc        45        21   0.0      ingame
# xShadowStriker        sell       pc        50         1   0.0      ingame
# KookyGreen            sell       pc        50        10   0.0      ingame
# Nectras               sell       pc        50         2   0.0      ingame
# PlaNeptunes           sell       pc        50         3   0.0      ingame
#
#                  visible
# Arcane Guardian
# streetknowledge     True
# xShadowStriker      True
# KookyGreen          True
# Nectras             True
# PlaNeptunes         True

# %%
show_item_data("动量赋能", rank=3)
# Out:
# Get From: https://warframe.market/items/arcane_momentum
# 奥秘 Momentum
#                 order_type platform  platinum  quantity  rank user_status  \
# Arcane Momentum
# kem1x                 sell       pc        60         1   3.0      ingame
# Leopolid              sell       pc        70         1   3.0      ingame
# -CCC-Snow             sell       pc        75         1   3.0      ingame
# zWhiteKz              sell       pc        89         1   3.0      ingame
# CytusM                sell       pc        90         1   3.0      ingame
#
#                  visible
# Arcane Momentum
# kem1x               True
# Leopolid            True
# -CCC-Snow           True
# zWhiteKz            True
# CytusM              True

# %%
show_item_data("狂怒赋能")
# Out:
# Get From: https://warframe.market/items/arcane_fury
# 奥秘 狂暴
#               order_type platform  platinum  quantity  rank user_status  \
# Arcane Fury
# xTerminatorxx       sell       pc        49         2   0.0      ingame
# gunnydesu           sell       pc        50         1   0.0      ingame
# Doggeday_xD         sell       pc        50         1   0.0      ingame
# TomixComix          sell       pc        55         1   0.0      ingame
# reppaas             sell       pc        59         1   0.0      ingame
#
#                visible
# Arcane Fury
# xTerminatorxx     True
# gunnydesu         True
# Doggeday_xD       True
# TomixComix        True
# reppaas           True

# %%
show_item_data("充沛赋能")
# Out:
# Get From: https://warframe.market/items/arcane_energize
# 充沛赋能
#                 order_type platform  platinum  quantity  rank user_status  \
# Arcane Energize
# Nutoru                sell       pc       199         1   0.0      ingame
# Nekraxiz              sell       pc       200         2   0.0      ingame
# MesarusAleXx166       sell       pc       229         1   0.0      ingame
# timwmpc               sell       pc       230         1   0.0      ingame
# xhibit                sell       pc       249         1   0.0      ingame
#
#                  visible
# Arcane Energize
# Nutoru              True
# Nekraxiz            True
# MesarusAleXx166     True
# timwmpc             True
# xhibit              True

# %%
info = get_item_data("充沛赋能")
# Out:
# Get From: https://warframe.market/items/arcane_energize

# %%
df = orders2df(info)
filt_orders(df).head()
# Out:
#                 order_type platform  platinum  quantity  rank user_status  \
# Arcane Energize
# Shivashanilly         sell       pc       200         1   0.0      ingame
# lWrathOfWarl          sell       pc       250         1   0.0      ingame
# -CM-HarKOn3N          sell       pc       250         2   0.0      ingame
# TengStz               sell       pc       250         1   0.0      ingame
# WWolfMaster           sell       pc       285         1   0.0      ingame
#
#                  visible
# Arcane Energize
# Shivashanilly       True
# lWrathOfWarl        True
# -CM-HarKOn3N        True
# TengStz             True
# WWolfMaster         True

# %%
Carrier = get_set_data("Carrier")
# Out:
# Get From: https://warframe.market/items/carrier_prime_set
# 搬运者 Prime Set
# 98
# Get From: https://warframe.market/items/carrier_prime_blueprint
# 搬运者 Prime 蓝图
# 5
# Get From: https://warframe.market/items/carrier_prime_cerebrum
# 搬运者 Prime 头部
# 85
# Get From: https://warframe.market/items/carrier_prime_carapace
# 搬运者 Prime 外壳
# 15
# Get From: https://warframe.market/items/carrier_prime_systems
# 搬运者 Prime 系统
# 4
# 109

# %%
Mag = get_set_data("Mag")
# Out:
# Get From: https://warframe.market/items/mag_prime_set
# Mag Prime Set
# 175
# Get From: https://warframe.market/items/mag_prime_neuroptics
# Mag Prime 头部神经光元
# 14
# Get From: https://warframe.market/items/mag_prime_systems
# Mag Prime 系统
# 60
# Get From: https://warframe.market/items/mag_prime_blueprint
# Mag Prime 蓝图
# 70
# Get From: https://warframe.market/items/mag_prime_chassis
# Mag Prime 机体
# 9
# 153

# %%
Zephyr = get_set_data("Zephyr")
# Out:
# Get From: https://warframe.market/items/zephyr_prime_set
# Zephyr
# 10
# Get From: https://warframe.market/items/zephyr_prime_neuroptics
# Zephyr Prime Neuroptics
# 15
# Get From: https://warframe.market/items/zephyr_prime_blueprint
# Zephyr Prime Blueprint
# 40
# Get From: https://warframe.market/items/zephyr_prime_chassis
# Zephyr Prime Chassis
# 25
# Get From: https://warframe.market/items/zephyr_prime_systems
# Zephyr Prime Systems
# 67
# 147

# %%
nyx = get_set_data("Nyx")
# Out:
# Get From: https://warframe.market/items/nyx_prime_set
# Nyx
# 370
# Get From: https://warframe.market/items/nyx_prime_neuroptics
# Nyx Prime Neuroptics
# 75
# Get From: https://warframe.market/items/nyx_prime_blueprint
# Nyx Prime Blueprint
# 3
# Get From: https://warframe.market/items/nyx_prime_chassis
# Nyx Prime Chassis
# 240
# Get From: https://warframe.market/items/nyx_prime_systems
# Nyx Prime Systems
# 15
# 333

# %%
bo = get_set_data("Bo")
# Out:
# Get From: https://warframe.market/items/bo_prime_set
# 玻之武杖 Prime Set
# 90
# Get From: https://warframe.market/items/bo_prime_blueprint
# 玻之武杖 Prime 蓝图
# 6
# Get From: https://warframe.market/items/bo_prime_handle
# 玻之武杖 Prime 握柄
# 14
# Get From: https://warframe.market/items/bo_prime_ornament
# 玻之武杖 Prime 饰物
# 20
# 40

# %%
show_item_data("高压电流")
# Out:
# Get From: https://warframe.market/items/high_voltage
# 高压电流
#                 order_type platform  platinum  quantity  rank user_status  \
# High Voltage
# niyomatrix            sell       pc        60         1     0      ingame
# Treemonkey            sell       pc        70         1     0      ingame
# Spikey                sell       pc        74         1     0      ingame
# NoobestofAllTym       sell       pc        75         1     0      ingame
# Genera1Chaos          sell       pc        75         1     0      ingame
#
#                  visible
# High Voltage
# niyomatrix          True
# Treemonkey          True
# Spikey              True
# NoobestofAllTym     True
# Genera1Chaos        True

# %%
show_item_data("电冲弹药")
# Out:
# Get From: https://warframe.market/items/shell_shock
# Shell 电击
#              order_type platform  platinum  quantity  rank user_status  \
# Shell Shock
# ChikkyNuggs        sell       pc        95         1     3      ingame
# -Uncle_Cat-        sell       pc       100         1     0      ingame
# MicaelVieira       sell       pc       100         1     0      ingame
# MintsMeans         sell       pc       109         1     0      ingame
# MarioZzQC          sell       pc       120         2     0      ingame
#
#               visible
# Shell Shock
# ChikkyNuggs      True
# -Uncle_Cat-      True
# MicaelVieira     True
# MintsMeans       True
# MarioZzQC        True

# %%
show_item_data("能量转换")
# Out:
# Get From: https://warframe.market/items/energy_conversion
# 能量转换
#                   order_type platform  platinum  quantity  rank user_status  \
# Energy Conversion
# MSN-100                 sell       pc        45         1     0      ingame
# played_out              sell       pc        45         1     0      ingame
# SpartanFaez96           sell       pc        45         1     0      ingame
# pocf                    sell       pc        47         1     0      ingame
# Rhui                    sell       pc        50         1     0      ingame
#
#                    visible
# Energy Conversion
# MSN-100               True
# played_out            True
# SpartanFaez96         True
# pocf                  True
# Rhui                  True

# %%
show_item_data("成长之力")
# Out:
# Get From: https://warframe.market/items/growing_power
# 成长之力
#                 order_type platform  platinum  quantity  rank user_status  \
# Growing Power
# Cheri                 sell       pc        46         1     0      ingame
# SnowmanOne            sell       pc        48         1     0      ingame
# Parasim               sell       pc        49         2     0      ingame
# Rebekha               sell       pc        49        11     0      ingame
# SeriousNinjaBug       sell       pc        49         2     0      ingame
#
#                  visible
# Growing Power
# Cheri               True
# SnowmanOne          True
# Parasim             True
# Rebekha             True
# SeriousNinjaBug     True

# %%
show_item_data("预言神密")
# Out:
# Get From: https://warframe.market/items/augur_secrets
# 预言神密
#               order_type platform  platinum  quantity  rank user_status  \
# Augur Secrets
# sasori66            sell       pc        95         1     1      ingame
# xtaezx              sell       pc        95         1     0      ingame
# ChaoCiao            sell       pc        99         1     0      ingame
# benny052            sell       pc        99         1     0      ingame
# Julius_War          sell       pc       100         1     0      ingame
#
#                visible
# Augur Secrets
# sasori66          True
# xtaezx            True
# ChaoCiao          True
# benny052          True
# Julius_War        True

# %%
sheev = get_set_data("希芙")
# Out:
# Get From: https://warframe.market/items/sheev_set
# 希芙
# 44
# Get From: https://warframe.market/items/sheev_blade
# Sheev Blade
# 10
# Get From: https://warframe.market/items/sheev_blueprint
# Sheev Blueprint
# 13
# Get From: https://warframe.market/items/sheev_heatsink
# Sheev Heatsink
# 12
# Get From: https://warframe.market/items/sheev_hilt
# Sheev Hilt
# 20
# 55

# %%
dera = get_set_data("德拉")
# Out:
# Get From: https://warframe.market/items/dera_vandal_set
# 德拉 破坏者 Set
# 35
# Get From: https://warframe.market/items/dera_vandal_blueprint
# 德拉 破坏者 蓝图
# 8
# Get From: https://warframe.market/items/dera_vandal_barrel
# 德拉 破坏者 枪管
# 7
# Get From: https://warframe.market/items/dera_vandal_receiver
# 德拉 破坏者 枪机
# 11
# Get From: https://warframe.market/items/dera_vandal_stock
# 德拉 破坏者 枪托
# 14
# 40
